# %% [markdown]
# # Bài 1
# ![image.png](attachment:image.png)

# %%
diem_toan = 5
diem_ly = 5.5
diem_hoa = 6
diem_trung_binh = (diem_toan + diem_ly + diem_hoa) / 3
print(diem_trung_binh)
print(diem_trung_binh >= 8)
print(6 <= diem_trung_binh < 8)
print(diem_trung_binh < 6)
# Out:
# 5.5
# False
# False
# True

# %% [markdown]
# # Bài 2
# ![image.png](attachment:image.png)

# %%
participation_percent = 80
course_complete_percent = 85
final_exam_mark = 7.5
print(participation_percent > 75 and course_complete_percent > 80 and final_exam_mark >= 7.5)
# Out:
# True

# %% [markdown]
# # Bài 3
# ![image.png](attachment:image.png)

# %%
velocity_km = 33
velocity_per_min_km = velocity_km / 60
velocity_per_min_m = velocity_per_min_km * 1000
print(velocity_per_min_m)
distance_72min = velocity_per_min_km * 72
print(distance_72min)
# Out:
# 550.0
# 39.6

# %% [markdown]
# # Bài 4
# ![image.png](attachment:image.png)

# %%
length = 16
width = 10

current_area = length * width
new_area = (length + 4) * width

result = (new_area - current_area) / current_area * 100
print(result)
# Out:
# 25.0

# %% [markdown]
# # Bài 5
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
v_xemay = 36
v_xedap = 12
khoang_cach = 48

hieu_van_toc = v_xemay - v_xedap
t_gapnhau = khoang_cach / hieu_van_toc
print(t_gapnhau)
# Out:
# 2.0
